# %%
import pandas as pd

df = pd.read_csv('lexicon_based_sentiment_emotions.csv')

df = df.dropna(subset=['date'])

df['date'] = df['date'].str.strip()

df['date'] = pd.to_datetime(df['date'], format='%B %d, %Y', errors='coerce')

df = df.dropna(subset=['date'])

df['date'] = df['date'].dt.strftime('%Y-%m-%d')

df.to_csv('lexicon_based_sentiment_emotions_2.csv',index=False)
# Out:
#                                      flavour        user_name  rating
# 0                             Salted Caramel    Peter_the_Gr8     4.0  \
# 1                Chocolate Raspberry Truffle  Sherry Mitchell     5.0
# 2                Chocolate Raspberry Truffle           VinRob     5.0
# 3                      Vanilla Pumpkin Spice              Fae     4.0
# 4                Chocolate Raspberry Truffle       Lashlouise     5.0
# ...                                      ...              ...     ...
# 4221  Crazy Cups Flavored Variety Pack Decaf  Barb O'Sullivan     5.0
# 4222  Crazy Cups Flavored Variety Pack Decaf          S. Sisk     5.0
# 4223           Chocolate Lovers Variety Pack      yukicharley     5.0
# 4224  Crazy Cups Flavored Variety Pack Decaf      MaggieMcfly     5.0
# 4225  Crazy Cups Flavored Variety Pack Decaf           Vimbai     5.0
#
#                               title
# 0        Good coffee, bad packaging  \
# 1              Third try is a charm
# 2                Perfect Flavor!!!!
# 3          Not bad, could be better
# 4                    Awesome Flavor
# ...                             ...
# 4221  Very fun and awesome flavors!
# 4222         Great customer service
# 4223                  Great flavors
# 4224                  Great Variety
# 4225                 Great Product!
#
#                                      review_description        date
# 0     I enjoy this coffee. It's an excellent taste w...  2023-06-14  \
# 1     It took me 3x (3 different kcup brands) to fin...  2023-06-10
# 2     WAs looking forward to trying this flavor and ...  2023-05-23
# 3     I've come to really love this brand, but of co...  2023-03-12
# 4          Love the flavor. Will definitely buy again!!  2023-06-16
# ...                                                 ...         ...
# 4221  When I want a special cup of coffee, I pick ou...  2022-05-26
# 4222  Awesome customer service. I received a sampler...  2021-03-11
# 4223  I love sampler packs. I love that I can try al...  2020-01-01
# 4224                 I’m very pleased with my purchase.  2022-09-02
# 4225  i got these for my boyfriend for christmas and...  2022-04-06
#
#                    country                                    cleaned_reviews
# 0         United States 🇺🇸  i enjoy this coffee. it's an excellent taste w...  \
# 1         United States 🇺🇸  it took me 3x (3 different kcup brands) to fin...
# 2         United States 🇺🇸  was looking forward to trying this flavor and ...
# 3         United States 🇺🇸  i've come to really love this brand, but of co...
# 4         United States 🇺🇸       love the flavor. will definitely buy again!!
# ...                    ...                                                ...
# 4221  the United States 🇺🇸  when i want a special cup of coffee, i pick ou...
# 4222  the United States 🇺🇸  awesome customer service. i received a sampler...
# 4223  the United States 🇺🇸  i love sampler packs. i love that i can try al...
# 4224  the United States 🇺🇸                 i’m very pleased with my purchase.
# 4225  the United States 🇺🇸  i got these for my boyfriend for christmas and...
#
#       afinn_score  bing_score  ...     anger anticipation   disgust      fear
# 0             6.0         6.0  ...  0.066667     0.266667  0.000000  0.066667  \
# 1             4.0         4.0  ...  0.000000     0.000000  0.000000  0.000000
# 2             7.0         5.0  ...  0.074074     0.111111  0.074074  0.000000
# 3             1.0         3.0  ...  0.071429     0.071429  0.071429  0.071429
# 4             3.0         3.0  ...  0.000000     0.000000  0.000000  0.000000
# ...           ...         ...  ...       ...          ...       ...       ...
# 4221          4.0         4.0  ...  0.000000     0.200000  0.000000  0.000000
# 4222         11.0        11.0  ...  0.142857     0.107143  0.000000  0.035714
# 4223         21.0        17.0  ...  0.000000     0.000000  0.000000  0.000000
# 4224          3.0         3.0  ...  0.000000     0.181818  0.000000  0.000000
# 4225         12.0         8.0  ...       NaN          NaN       NaN       NaN
#
#            joy  negative  positive   sadness  surprise     trust
# 0     0.133333  0.133333  0.200000  0.000000  0.000000  0.133333
# 1     0.250000  0.250000  0.500000  0.000000  0.000000  0.000000
# 2     0.111111  0.111111  0.222222  0.111111  0.000000  0.185185
# 3     0.071429  0.214286  0.214286  0.142857  0.000000  0.071429
# 4     0.500000  0.000000  0.500000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...
# 4221  0.200000  0.000000  0.400000  0.000000  0.000000  0.200000
# 4222  0.214286  0.071429  0.250000  0.035714  0.035714  0.107143
# 4223  0.500000  0.000000  0.500000  0.000000  0.000000  0.000000
# 4224  0.181818  0.000000  0.272727  0.000000  0.181818  0.181818
# 4225       NaN       NaN       NaN       NaN       NaN       NaN
#
# [4225 rows x 22 columns]
